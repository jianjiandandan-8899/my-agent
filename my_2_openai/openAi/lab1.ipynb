# %%
from dotenv import load_dotenv
from openai import AsyncOpenAI
import os
from agents import Agent, Runner, trace
from agents.models.openai_provider import OpenAIProvider
from agents.run import RunConfig

# %%
load_dotenv(dotenv_path="/Users/jane/Desktop/claude-code-projects/agent/agents/my_2_openai/.env", override=True)

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

client = AsyncOpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
run_config = RunConfig(model_provider=OpenAIProvider(openai_client=client))

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="openai/gpt-4o-mini")

# %%
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents", run_config=run_config)
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# Because it just couldn't reconcile their differences in algorithm!
