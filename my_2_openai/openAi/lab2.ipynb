# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
import asyncio
from agents.models.openai_provider import OpenAIProvider
from agents.run import RunConfig
from openai import AsyncOpenAI

# %%
load_dotenv(dotenv_path="/Users/jane/Desktop/claude-code-projects/agent/agents/my_2_openai/.env", override=True)

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

client = AsyncOpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
run_config = RunConfig(model_provider=OpenAIProvider(openai_client=client))

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini"
)

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message, run_config=run_config),
        Runner.run(sales_agent2, message, run_config=run_config),
        Runner.run(sales_agent3, message, run_config=run_config),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# Subject: Simplify Your SOC2 Compliance with ComplAI
#
# Dear [Recipient's Name],
#
# I hope this message finds you well. My name is [Your Name], and I am reaching out from ComplAI, where we specialize in streamlining SOC2 compliance and audit preparation processes through our powerful AI-driven platform.
#
# In today’s regulatory environment, ensuring compliance while managing time and resources can be a complex challenge. ComplAI is designed to simplify this process, providing your team with the tools needed to efficiently manage documentation, automate workflows, and stay ahead of compliance requirements.
#
# With our solution, you can expect:
#
# 1. **Automated Documentation**: Reduce manual tasks with our intelligent algorithm that generates compliance documents tailored to your specific needs.
# 2. **Real-Time Monitoring**: Stay updated with your compliance status through continuous tracking and alerts, enabling proactive measures.
# 3. **Seamless Audit Preparation**: Navigate audits with confidence, armed with comprehensive reports and audit trails at your fingertips.
#
# Many organizations have found significant time savings and improved accuracy with our platform. I would love the opportunity to discuss how ComplAI can support your compliance efforts and enhance your readiness for audits.
#
# Are you available for a brief call this week? I look forward to your response.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# ComplAI
# [Your Contact Information]
# [Your LinkedIn Profile (if applicable)]
#
#
# Subject: Is Your SOC2 Compliance Feeling a Little... "Unprepared"? 😅
#
# Hey [Recipient's Name],
#
# I hope this email finds you well and not drowning in a sea of compliance documents!
#
# If your SOC2 compliance feels more like a wild goose chase than a smooth sailing cruise, I’ve got some good news — not all heroes wear capes, but they do have access to ComplAI!
#
# Here’s how we can rescue you from compliance chaos:
#
# 🚀 **Powered by AI**: Imagine a world where preparing for audits is as easy as pie. Our tool automates the heavy lifting so you can focus on more pressing matters, like perfecting your coffee order or taking a well-deserved break.
#
# 📊 **Stay Compliance Confident**: With insights sharper than your favorite superhero's sword, we’ll help you stay ahead of the curve and dodge those pesky audit surprises.
#
# 💡 **User-Friendly**: Our interface is so intuitive, even your grandma could use it to achieve compliance (and believe me, she’d be impressed!).
#
# Want to join the elite squad of companies effortlessly gliding through audits? Let’s schedule a quick call—I'll bring the superhero puns!
#
# Looking forward to your reply!
#
# Best,
# [Your Name]
# [Your Position]
# ComplAI
# [Your Contact Information]
# P.S. No capes required for SOC2 compliance, just smart tools! 🦸‍♂️
#
#
# Subject: Simplify Your SOC2 Compliance Process
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. As a busy professional, I understand the challenges of managing SOC2 compliance and audit preparations.
#
# At ComplAI, we offer an AI-powered SaaS tool that streamlines the compliance process, helping you save time and reduce stress. Our solution automates documentation, tracks requirements, and ensures you're always audit-ready.
#
# Would you be open to a brief call next week to discuss how we can help your team simplify compliance?
#
# Best,
# [Your Name]
# [Your Position]
# ComplAI
# [Your Phone Number]
# [Your Email Address]
# [Your Website]
# OPENAI_API_KEY is not set, skipping trace export
